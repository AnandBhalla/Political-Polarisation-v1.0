# %%
import pandas as pd

# %%
df = pd.read_csv("Trump_data.csv")
display(df)
# Out:
#         channel  topic sentiment category subjectivity category
# 0      Fox News  Trump              FAVOR             OBJECTIVE
# 1      Fox News  Trump              FAVOR             OBJECTIVE
# 2      Fox News  Trump              FAVOR             OBJECTIVE
# 3      Fox News  Trump              FAVOR             OBJECTIVE
# 4      Fox News  Trump              FAVOR             OBJECTIVE
# ...         ...    ...                ...                   ...
# 12686  CBS News  Trump           MODERATE             OBJECTIVE
# 12687  CBS News  Trump              FAVOR             OBJECTIVE
# 12688  CBS News  Trump              FAVOR             OBJECTIVE
# 12689  CBS News  Trump           MODERATE             OBJECTIVE
# 12690  CBS News  Trump           MODERATE             OBJECTIVE
#
# [12691 rows x 4 columns]

# %%
df = pd.read_csv("Clinton_data.csv")
display(df)
# Out:
#       channel    topic sentiment category subjectivity category
# 0    Fox News  Clinton              FAVOR             OBJECTIVE
# 1    Fox News  Clinton              FAVOR             OBJECTIVE
# 2    Fox News  Clinton              FAVOR             OBJECTIVE
# 3    Fox News  Clinton              FAVOR             OBJECTIVE
# 4    Fox News  Clinton           MODERATE             OBJECTIVE
# ..        ...      ...                ...                   ...
# 206  CBS News  Clinton           MODERATE             OBJECTIVE
# 207  CBS News  Clinton           MODERATE             OBJECTIVE
# 208  CBS News  Clinton              FAVOR            SUBJECTIVE
# 209  CBS News  Clinton           MODERATE             OBJECTIVE
# 210  CBS News  Clinton              FAVOR             OBJECTIVE
#
# [211 rows x 4 columns]

# %%
df = pd.read_csv("Obama_data.csv")
display(df)
# Out:
#       channel         topic sentiment category subjectivity category
# 0    Fox News         Obama              FAVOR             OBJECTIVE
# 1    Fox News         Obama              FAVOR             OBJECTIVE
# 2    Fox News  Trump, Obama              FAVOR             OBJECTIVE
# 3    Fox News         Obama              FAVOR             OBJECTIVE
# 4    Fox News         Obama              FAVOR             OBJECTIVE
# ..        ...           ...                ...                   ...
# 324  CBS News         Obama           MODERATE             OBJECTIVE
# 325  CBS News         Obama           MODERATE             OBJECTIVE
# 326  CBS News         Obama           MODERATE             OBJECTIVE
# 327  CBS News         Obama           MODERATE             OBJECTIVE
# 328  CBS News         Obama           MODERATE             OBJECTIVE
#
# [329 rows x 4 columns]

# %%
df = pd.read_csv("Liberals_data.csv")
display(df)
# Out:
#       channel     topic sentiment category subjectivity category
# 0    Fox News  Liberals              FAVOR             OBJECTIVE
# 1    Fox News  Liberals              FAVOR             OBJECTIVE
# 2    Fox News  Liberals              FAVOR             OBJECTIVE
# 3    Fox News  Liberals              FAVOR             OBJECTIVE
# 4    Fox News  Liberals              FAVOR             OBJECTIVE
# ..        ...       ...                ...                   ...
# 249     MSNBC  Liberals           MODERATE             OBJECTIVE
# 250     MSNBC  Liberals           MODERATE             OBJECTIVE
# 251  CBS News  Liberals              FAVOR             OBJECTIVE
# 252  CBS News  Liberals              FAVOR             OBJECTIVE
# 253  CBS News  Liberals              FAVOR             OBJECTIVE
#
# [254 rows x 4 columns]

# %%
df = pd.read_csv("Conservatives_data.csv")
display(df)
# Out:
#       channel                       topic sentiment category  \
# 0    Fox News  Republicans, Conservatives              FAVOR
# 1    Fox News     Liberals, Conservatives              FAVOR
# 2    Fox News               Conservatives              FAVOR
# 3    Fox News               Conservatives              FAVOR
# 4    Fox News               Conservatives              FAVOR
# ..        ...                         ...                ...
# 173  CBS News               Conservatives           MODERATE
# 174  CBS News               Conservatives              FAVOR
# 175  CBS News               Conservatives           MODERATE
# 176  CBS News               Conservatives           MODERATE
# 177  CBS News               Conservatives           MODERATE
#
#     subjectivity category
# 0               OBJECTIVE
# 1               OBJECTIVE
# 2               OBJECTIVE
# 3               OBJECTIVE
# 4               OBJECTIVE
# ..                    ...
# 173             OBJECTIVE
# ...

# %%
df = pd.read_csv("Democrats_data.csv")
display(df)
# Out:
#        channel      topic sentiment category subjectivity category
# 0     Fox News  Democrats              FAVOR             OBJECTIVE
# 1     Fox News  Democrats              FAVOR             OBJECTIVE
# 2     Fox News  Democrats              FAVOR             OBJECTIVE
# 3     Fox News  Democrats              FAVOR             OBJECTIVE
# 4     Fox News  Democrats              FAVOR             OBJECTIVE
# ...        ...        ...                ...                   ...
# 1308  CBS News  Democrats           MODERATE             OBJECTIVE
# 1309  CBS News  Democrats              FAVOR             OBJECTIVE
# 1310  CBS News  Democrats           MODERATE             OBJECTIVE
# 1311  CBS News  Democrats           MODERATE             OBJECTIVE
# 1312  CBS News  Democrats           MODERATE             OBJECTIVE
#
# [1313 rows x 4 columns]

# %%
df = pd.read_csv("Republicans_data.csv")
display(df)
# Out:
#        channel        topic sentiment category subjectivity category
# 0     Fox News  Republicans              FAVOR             OBJECTIVE
# 1     Fox News  Republicans              FAVOR             OBJECTIVE
# 2     Fox News  Republicans              FAVOR             OBJECTIVE
# 3     Fox News  Republicans              FAVOR             OBJECTIVE
# 4     Fox News  Republicans              FAVOR             OBJECTIVE
# ...        ...          ...                ...                   ...
# 1832  CBS News  Republicans           MODERATE             OBJECTIVE
# 1833  CBS News  Republicans              FAVOR            SUBJECTIVE
# 1834  CBS News  Republicans           MODERATE             OBJECTIVE
# 1835  CBS News  Republicans           MODERATE             OBJECTIVE
# 1836  CBS News  Republicans           MODERATE             OBJECTIVE
#
# [1837 rows x 4 columns]

# %%
df = pd.read_csv("videos.csv")
display(df)
# Out:
#         youtube_id                                              title  \
# 0      9PUr5j1_ZnI  'Bombshell' text messages revealed in Fani Wil...
# 1      OEJeX1US4Hg  'HISTORIC': Biden SLAMMED over 'biggest nation...
# 2      FJLjOdc27QM  'Election interference': 3rd state removes Tru...
# 3      UZwSwxUcYjE  Hunter Biden had 'bizarre' defense at House he...
# 4      Ntq0GmXWyvI  ‘The Five’: Kamala applauds ‘progressive prose...
# ...            ...                                                ...
# 78707  ZE0zm2O6L0o    Inflation slows for the first time since August
# 78708  qVffFcCNUAc  Apple discontinuing the iPod after more than 2...
# 78709  B9jlvwvI838  Democrats work to save abortion rights as Supr...
# 78710  SW-tJCUM8VA  Senate Democrats push to codify abortion right...
# 78711  pORe-DIfsGA  Journalist killed while covering Israeli raid ...
#
#                                              description  \
# 0      Constitutional law attorney Katie Cherkasky jo...
# ...

# %%
df = pd.read_csv("result.csv")
display(df)
# Out:
#                                                    title        topic  \
# 0      'Election interference': 3rd state removes Tru...        Trump
# 1      Trump gets partial victory in NY civil fraud a...        Trump
# 2      Ted Nugent: Trump 'nailed it' at the border - ...        Trump
# 3                       Trump: Texas is now a ‘war zone’        Trump
# 4           Ingraham: Democrats are in political trouble    Democrats
# ...                                                  ...          ...
# 16089  Democratic and Republican political strategies...  Republicans
# 16090  Examining Trump's influence in the 2022 primaries        Trump
# 16091  Senate Republicans block bill to make Roe v. W...  Republicans
# 16092  Democrats work to save abortion rights as Supr...    Democrats
# 16093  Senate Democrats push to codify abortion right...    Democrats
#
#                                              description  sentiment score  \
# ...

# %%
df = pd.read_csv("Fox News_data.csv")
display(df)
# Out:
#                                                   title        topic  \
# 0     'Election interference': 3rd state removes Tru...        Trump
# 1     Trump gets partial victory in NY civil fraud a...        Trump
# 2     Ted Nugent: Trump 'nailed it' at the border - ...        Trump
# 3                      Trump: Texas is now a ‘war zone’        Trump
# 4          Ingraham: Democrats are in political trouble    Democrats
# ...                                                 ...          ...
# 2875  FBI whistleblowers come forward regarding Hunt...        Trump
# 2876                 This is totally insane: Lara Trump        Trump
# 2877  Republican AGs urge Google not to censor pro-l...  Republicans
# 2878  Tomi Lahren: This shows how 'out-of-touch' Dem...    Democrats
# 2879  We need more Republicans to say climate change...  Republicans
#
#                                             description  sentiment score  \
# ...

# %%
df = pd.read_csv("CNN_data.csv")
display(df)
# Out:
#                                                   title          topic  \
# 0     Republican senator says immigrants ‘know nothi...    Republicans
# 1     Ex-Trump impeachment lawyer explains the dispu...          Trump
# 2     Trump floats possible abortion ban. See what H...          Trump
# 3     Hear Van Jones’ surprising conversation with d...  Conservatives
# 4     Former judge warns Trump ‘might get what he’s ...          Trump
# ...                                                 ...            ...
# 5219  Cooper lists the times Trump hasn't denounced ...          Trump
# 5220  Burnett: Trump realized a Fox guy can't change...          Trump
# 5221  Kellyanne Conway's husband blasts Trump in rar...          Trump
# 5222  Ken Starr and Joe Lockhart spar over Trump and...          Trump
# 5223  Clinton impeachment foes butt heads over Lewin...        Clinton
#
#                                             description  sentiment score  \
# ...

# %%
df = pd.read_csv("CBS News_data.csv")
display(df)
# Out:
#                                                   title        topic  \
# 0     House Republicans release 5,000 hours of unsee...  Republicans
# 1     Judge appears skeptical of July trial date in ...        Trump
# 2     Blizzard slams California, Trump attends Flori...        Trump
# 3     Judge hears arguments on whether Fani Willis s...        Trump
# 4     Trump's attorney questions Fani Willis-Nathan ...        Trump
# ...                                                 ...          ...
# 2329  Democratic and Republican political strategies...  Republicans
# 2330  Examining Trump's influence in the 2022 primaries        Trump
# 2331  Senate Republicans block bill to make Roe v. W...  Republicans
# 2332  Democrats work to save abortion rights as Supr...    Democrats
# 2333  Senate Democrats push to codify abortion right...    Democrats
#
#                                             description  sentiment score  \
# ...

# %%
df = pd.read_csv("Clinton_data.csv")
display(df)
# Out:
#       channel    topic sentiment category subjectivity category
# 0    Fox News  Clinton              FAVOR             OBJECTIVE
# 1    Fox News  Clinton              FAVOR             OBJECTIVE
# 2    Fox News  Clinton              FAVOR             OBJECTIVE
# 3    Fox News  Clinton              FAVOR             OBJECTIVE
# 4    Fox News  Clinton           MODERATE             OBJECTIVE
# ..        ...      ...                ...                   ...
# 206  CBS News  Clinton           MODERATE             OBJECTIVE
# 207  CBS News  Clinton           MODERATE             OBJECTIVE
# 208  CBS News  Clinton              FAVOR            SUBJECTIVE
# 209  CBS News  Clinton           MODERATE             OBJECTIVE
# 210  CBS News  Clinton              FAVOR             OBJECTIVE
#
# [211 rows x 4 columns]

# %%
df = pd.read_csv("MSNBC_data.csv")
display(df)
# Out:
#                                                   title          topic  \
# 0     The Nightcap: Trump cases pushed closer to ele...          Trump
# 1     Threat of Trump undoing American democracy ‘ve...          Trump
# 2     Big day for Trump’s criminal trials in Georgia...          Trump
# 3     Trump effect: Justice system ‘bends over backw...          Trump
# 4     SCOTUS torn on 'shooting device so horrifying ...          Trump
# ...                                                 ...            ...
# 5651  Why Trump Will ‘Strike Out’ With His Supreme C...          Trump
# 5652  Michael Cohen: Placating Trump’s Behavior Only...          Trump
# 5653  Conservatives Stuck In 'Zero Sum' Mindset See ...  Conservatives
# 5654  Lawrence: Where Else Did Trump Leave His Belov...          Trump
# 5655  What Else Is There At 'Other Properties Trump ...          Trump
#
#                                             description  sentiment score  \
# ...

# %%
df = pd.read_csv("MODERATE_data.csv")
display(df)
# Out:
#                                                   title        topic  \
# 0     Fun facts about Larry Kudlow, from Wall Street...        Trump
# 1     Democrat rips House dems for handling of Hunte...    Democrats
# 2     Epstein doc bombshell: Bill Clinton 'threatene...      Clinton
# 3     Former Obama official arrested following viral...        Obama
# 4          Trump: America is 'finished' if this happens        Trump
# ...                                                 ...          ...
# 8442  Democratic and Republican political strategies...  Republicans
# 8443  Examining Trump's influence in the 2022 primaries        Trump
# 8444  Senate Republicans block bill to make Roe v. W...  Republicans
# 8445  Democrats work to save abortion rights as Supr...    Democrats
# 8446  Senate Democrats push to codify abortion right...    Democrats
#
#                                             description  sentiment score  \
# ...

# %%
df = pd.read_csv("AGAINST_data.csv")
display(df)
# Out:
#                                                  title           topic  \
# 0    Legal expert details what New York ruling mean...           Trump
# 1    Dumb, shameful, dangerous, un-American: Biden ...           Trump
# 2    Report: Biden calls Trump a 'sick f***' in pri...           Trump
# 3    Attorney says Trump plans to testify. Court ad...           Trump
# 4    'Uncomfortable': CNN anchor reacts to Trump co...  Trump, Clinton
# ..                                                 ...             ...
# 237  ‘Absolutely disgusted’: Town hall audience mem...           Trump
# 238  Trump refers to town hall moderator as 'nasty ...           Trump
# 239  Guilty: Trump rioter who put feet on Pelosi’s ...           Trump
# 240  Democrats skeptical McCarthy can turn around h...       Democrats
# 241  Trump Faces One Setback After Another In Horri...           Trump
#
#                                            description  sentiment score  \
# ...

# %%
df = pd.read_csv("FAVOR_data.csv")
display(df)
# Out:
#                                                   title      topic  \
# 0     'Election interference': 3rd state removes Tru...      Trump
# 1     Trump gets partial victory in NY civil fraud a...      Trump
# 2     Ted Nugent: Trump 'nailed it' at the border - ...      Trump
# 3                      Trump: Texas is now a ‘war zone’      Trump
# 4          Ingraham: Democrats are in political trouble  Democrats
# ...                                                 ...        ...
# 4862  GOP primary election results in Georgia signal...      Trump
# 4863   How Trump will influence Georgia primary results      Trump
# 4864   Trump's Truth Social fails to produce ad revenue      Trump
# 4865  Migrant families separated by Trump-era policy...      Trump
# 4866  New York judge lifts contempt finding against ...      Trump
#
#                                             description  sentiment score  \
# 0     'Outnumbered' panelists discuss the possible i...         0.290164
# ...
